# %% [markdown]
# # Phân loại số

# %%
Number = int(input("Nhập vào 1 số: "))
if(Number % 2 == 0):
    print(f"Số {Number} là số chẵn!")
else:
    print(f"Số {Number} là số lẻ!")
# Out:
# Số 1 là số lẻ!
