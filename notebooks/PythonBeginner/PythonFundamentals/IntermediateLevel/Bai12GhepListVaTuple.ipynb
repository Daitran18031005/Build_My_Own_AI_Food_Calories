# %% [markdown]
# # Ghép List và Tuple

# %%
ListA = [10, 20, 30]
TupleB = (40, 50, 60)

CombinedList = ListA + list(TupleB) # Ép kiểu TupleB thành List và nối hai list
print(f"Combined list: {CombinedList}")
# Out:
# Combined list: [10, 20, 30, 40, 50, 60]
