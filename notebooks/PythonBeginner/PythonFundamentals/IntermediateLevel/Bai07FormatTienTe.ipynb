# %% [markdown]
# # Format tiền tệ

# %%
# Nhập số nguyên
Money = int(input("Nhập số tiền: "))

# In số đó dưới dạng tiền tệ có dấu phẩy ngăn cách hàng nghìn
print(f"Số tiền đã nhập là: {Money:,} VND")
# Out:
# Số tiền đã nhập là: 123,000,123,000 VND
