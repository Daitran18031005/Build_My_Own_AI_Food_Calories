# %% [markdown]
# # Kiểm tra kí tự số

# %%
# Nhận 1 chuỗi
String = input("Nhập chuỗi: ")

# Kiểm tra tất cả kí tự trong chuỗi có phải kí tự số hay không
if (not String.isdigit()):
    print("False")
else:
    print("True")
# Out:
# False
