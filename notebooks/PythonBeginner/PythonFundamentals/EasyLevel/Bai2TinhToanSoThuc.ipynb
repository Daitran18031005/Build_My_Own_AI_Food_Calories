# %% [markdown]
# # Tính toán với số thực

# %%
# Nhập 2 số thực x và y
x = float(input("Nhập số thực x: "))
y = float(input("Nhập số thực y: "))

# Tính toán biểu thức: z = (x^2 + y)*(2x)
z = (x**2 + y) * (2 * x)
print(f"Kết quả z = {z}")
# Out:
# Kết quả z = 117.25
