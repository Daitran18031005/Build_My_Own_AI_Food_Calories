# %% [markdown]
# # Xử lý chuỗi phức tạp

# %%
# Nhập 1 câu
String = input("Nhập 1 câu: ")

# Thay thế tất cả khoảng trắng trong câu bằng dấu gạch ngang
String = String.replace(" ", "-")

# Kết quả
print(f"Câu: {String}")
# Out:
# Câu: Xin-chào-tất-cả-mọi-người
