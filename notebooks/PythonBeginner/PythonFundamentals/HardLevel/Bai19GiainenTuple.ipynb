# %% [markdown]
# # Giải nén Tuple (Unpacking)

# %%
Coordinates = [(1, 2), (3, 4), (5, 6)]

for Coordinate in Coordinates:
    x, y = Coordinate # Tách phần tử trong tuple thành x và y -> đây là kỹ thuật unpacking
    print(f"x = {x}, y = {y}")
# Out:
# x = 1, y = 2
# x = 3, y = 4
# x = 5, y = 6
