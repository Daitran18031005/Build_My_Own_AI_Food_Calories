# %% [markdown]
# # First Program

# %%
input("Enter somethings: ")
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# # Variable

# %%
SomeThings = input("Enter somethings: ")
print(f"you entered: {SomeThings}")
# Out:
# you entered: Hello World!

# %% [markdown]
# # Comments

# %%
#This is a Comment Line
"""
   This is a Comment Block
   One more line of comment
"""
# Out:
# '\n   This is a Comment Block\n   One more line of comment\n'

# %% [markdown]
# # Documentations

# %% [markdown]
# ## Read the Documents at:
#
# docs.python.org/3/library/functions.html#functionName
#
# ## To find out the answer

# %% [markdown]
# # String

# %%
# Ask user of their name
name = input ("What is your name? ")

# Remove white spaces from the string and capitalize user's name
name = name.strip().title()

# Split user's name into first name and last name
firstName, lastName = name.split(" ")

# Say hello to the user
print(f"Hello, {name}")
print(f"Hello, {firstName}")
# Out:
# Hello, Dai Tra
# Hello, Dai

# %% [markdown]
# # Int

# %%
x = int(input("Enter a number: "))
y = int(input("Enter another number: "))
z = x + y 
print(z)
# Out:
# 7
